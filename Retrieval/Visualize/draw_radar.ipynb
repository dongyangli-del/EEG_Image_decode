# %% [markdown]
# # Classification

# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/insubject'

# Function to calculate the maximums of the metrics
def calculate_maximums(file_path):
    df = pd.read_csv(file_path)
    maximums = {
        'v2_acc': df['v2_acc'].max(),
        'v4_acc': df['v4_acc'].max(),
        'v10_acc': df['v10_acc'].max(),
        'test_accuracy': df['test_accuracy'].max(),  # TOP1 accuracy
        'top5_acc': df['top5_acc'].max()  # TOP5 accuracy
    }
    return maximums

# Dictionary to store the results
results = {}

# Define the output file name
output_file_name = 'subject_averages.csv'

# Check if the output file already exists and skip it
output_file_path = os.path.join(directory_path, output_file_name)
if os.path.exists(output_file_path):
    os.remove(output_file_path)

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv') and filename != output_file_name:
        # Extract the method name from the filename
        method_name = filename.split('_')[0]
        file_path = os.path.join(directory_path, filename)
        maximums = calculate_maximums(file_path)
        
        # Aggregate the results by method name
        if method_name not in results:
            results[method_name] = {metric: [] for metric in maximums}
        for metric in maximums:
            results[method_name][metric].append(maximums[metric])

# Calculate the average for each method and metric
averages = {method: {metric: sum(values) / len(values) for metric, values in metrics.items()}
            for method, metrics in results.items()}

# Sort the results by method name
sorted_averages = dict(sorted(averages.items()))

# Convert the sorted averages dictionary to a pandas DataFrame for easier CSV output
averages_df = pd.DataFrame.from_dict(sorted_averages, orient='index')

# You may want to include more descriptive column names here
averages_df.columns = ['V2 Accuracy', 'V4 Accuracy', 'V10 Accuracy', 'Test Accuracy', 'Top5 Accuracy']

# Save the DataFrame to a CSV file
averages_df.to_csv(output_file_path, index_label='Method')

print(f"Averages saved to {output_file_path}")
# Out:
# Averages saved to /home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/insubject/subject_averages.csv

# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/cross_subject'

# Function to calculate the maximums of the metrics
def calculate_maximums(file_path):
    df = pd.read_csv(file_path)
    maximums = {
        'v2_acc': df['v2_acc'].max(),
        'v4_acc': df['v4_acc'].max(),
        'v10_acc': df['v10_acc'].max(),
        'test_accuracy': df['test_accuracy'].max(),  # TOP1 accuracy
        'top5_acc': df['top5_acc'].max()  # TOP5 accuracy
    }
    return maximums

# Dictionary to store the results
results = {}

# Define the output file name
output_file_name = 'subject_averages.csv'

# Check if the output file already exists and skip it
output_file_path = os.path.join(directory_path, output_file_name)
if os.path.exists(output_file_path):
    os.remove(output_file_path)

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv') and filename != output_file_name:
        # Extract the method name from the filename
        method_name = filename.split('_')[0]
        file_path = os.path.join(directory_path, filename)
        maximums = calculate_maximums(file_path)
        
        # Aggregate the results by method name
        if method_name not in results:
            results[method_name] = {metric: [] for metric in maximums}
        for metric in maximums:
            results[method_name][metric].append(maximums[metric])

# Calculate the average for each method and metric
averages = {method: {metric: sum(values) / len(values) for metric, values in metrics.items()}
            for method, metrics in results.items()}

# Sort the results by method name
sorted_averages = dict(sorted(averages.items()))

# Convert the sorted averages dictionary to a pandas DataFrame for easier CSV output
averages_df = pd.DataFrame.from_dict(sorted_averages, orient='index')

# You may want to include more descriptive column names here
averages_df.columns = ['V2 Accuracy', 'V4 Accuracy', 'V10 Accuracy', 'Test Accuracy', 'Top5 Accuracy']

# Save the DataFrame to a CSV file
averages_df.to_csv(output_file_path, index_label='Method')

print(f"Averages saved to {output_file_path}")
# Out:
# Averages saved to /home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/cross_subject/subject_averages.csv

# %% [markdown]
# # Retrieval

# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/insubject/batchsize=1024'

# Function to calculate the maximums of the metrics
def calculate_maximums(file_path):
    df = pd.read_csv(file_path)
    maximums = {
        'v2_acc': df['v2_acc'].max(),
        'v4_acc': df['v4_acc'].max(),
        'v10_acc': df['v10_acc'].max(),
        'test_accuracy': df['test_accuracy'].max(),  # TOP1 accuracy
        'top5_acc': df['top5_acc'].max()  # TOP5 accuracy
    }
    return maximums

# Dictionary to store the results
results = {}

# Define the output file name
output_file_name = 'subject_averages.csv'

# Check if the output file already exists and skip it
output_file_path = os.path.join(directory_path, output_file_name)
if os.path.exists(output_file_path):
    os.remove(output_file_path)

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv') and filename != output_file_name:
        # Extract the method name from the filename
        method_name = filename.split('_')[0]
        file_path = os.path.join(directory_path, filename)
        maximums = calculate_maximums(file_path)
        
        # Aggregate the results by method name
        if method_name not in results:
            results[method_name] = {metric: [] for metric in maximums}
        for metric in maximums:
            results[method_name][metric].append(maximums[metric])

# Calculate the average for each method and metric
averages = {method: {metric: sum(values) / len(values) for metric, values in metrics.items()}
            for method, metrics in results.items()}

# Sort the results by method name
sorted_averages = dict(sorted(averages.items()))

# Convert the sorted averages dictionary to a pandas DataFrame for easier CSV output
averages_df = pd.DataFrame.from_dict(sorted_averages, orient='index')

# You may want to include more descriptive column names here
averages_df.columns = ['V2 Accuracy', 'V4 Accuracy', 'V10 Accuracy', 'Test Accuracy', 'Top5 Accuracy']

# Save the DataFrame to a CSV file
averages_df.to_csv(output_file_path, index_label='Method')

print(f"Averages saved to {output_file_path}")
# Out:
# Averages saved to /home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/insubject/batchsize=1024/subject_averages.csv

# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/cross_subject/batchsize=1024'

# Function to calculate the maximums of the metrics
def calculate_maximums(file_path):
    df = pd.read_csv(file_path)
    maximums = {
        'v2_acc': df['v2_acc'].max(),
        'v4_acc': df['v4_acc'].max(),
        'v10_acc': df['v10_acc'].max(),
        'test_accuracy': df['test_accuracy'].max(),  # TOP1 accuracy
        'top5_acc': df['top5_acc'].max()  # TOP5 accuracy
    }
    return maximums

# Dictionary to store the results
results = {}

# Define the output file name
output_file_name = 'subject_averages.csv'

# Check if the output file already exists and skip it
output_file_path = os.path.join(directory_path, output_file_name)
if os.path.exists(output_file_path):
    os.remove(output_file_path)

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv') and filename != output_file_name:
        # Extract the method name from the filename
        method_name = filename.split('_')[0]
        file_path = os.path.join(directory_path, filename)
        maximums = calculate_maximums(file_path)
        
        # Aggregate the results by method name
        if method_name not in results:
            results[method_name] = {metric: [] for metric in maximums}
        for metric in maximums:
            results[method_name][metric].append(maximums[metric])

# Calculate the average for each method and metric
averages = {method: {metric: sum(values) / len(values) for metric, values in metrics.items()}
            for method, metrics in results.items()}

# Sort the results by method name
sorted_averages = dict(sorted(averages.items()))

# Convert the sorted averages dictionary to a pandas DataFrame for easier CSV output
averages_df = pd.DataFrame.from_dict(sorted_averages, orient='index')

# You may want to include more descriptive column names here
averages_df.columns = ['V2 Accuracy', 'V4 Accuracy', 'V10 Accuracy', 'Test Accuracy', 'Top5 Accuracy']

# Save the DataFrame to a CSV file
averages_df.to_csv(output_file_path, index_label='Method')

print(f"Averages saved to {output_file_path}")
# Out:
# Averages saved to /home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/cross_subject/batchsize=1024/subject_averages.csv

# %% [markdown]
# # Generation

# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = '/home/ldy/Workspace/BrainAligning_retrieval/generation_metric_outputs'

# Function to calculate the maximums of the metrics
def calculate_maximums(file_path):
    df = pd.read_csv(file_path)
    maximums = {
        'v2_acc': df['v2_acc'].max(),
        'v4_acc': df['v4_acc'].max(),
        'v10_acc': df['v10_acc'].max(),
        'test_accuracy': df['test_accuracy'].max(),  # TOP1 accuracy
        'top5_acc': df['top5_acc'].max()  # TOP5 accuracy
    }
    return maximums

# Dictionary to store the results
results = {}

# Define the output file name
output_file_name = 'subject_averages.csv'

# Check if the output file already exists and skip it
output_file_path = os.path.join(directory_path, output_file_name)
if os.path.exists(output_file_path):
    os.remove(output_file_path)

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv') and filename != output_file_name:
        # Extract the method name from the filename
        method_name = filename.split('_')[0]
        file_path = os.path.join(directory_path, filename)
        maximums = calculate_maximums(file_path)
        
        # Aggregate the results by method name
        if method_name not in results:
            results[method_name] = {metric: [] for metric in maximums}
        for metric in maximums:
            results[method_name][metric].append(maximums[metric])

# Calculate the average for each method and metric
averages = {method: {metric: sum(values) / len(values) for metric, values in metrics.items()}
            for method, metrics in results.items()}

# Sort the results by method name
sorted_averages = dict(sorted(averages.items()))

# Convert the sorted averages dictionary to a pandas DataFrame for easier CSV output
averages_df = pd.DataFrame.from_dict(sorted_averages, orient='index')

# You may want to include more descriptive column names here
averages_df.columns = ['V2 Accuracy', 'V4 Accuracy', 'V10 Accuracy', 'Test Accuracy', 'Top5 Accuracy']

# Save the DataFrame to a CSV file
averages_df.to_csv(output_file_path, index_label='Method')

print(f"Averages saved to {output_file_path}")
# Out:
# Averages saved to /home/ldy/Workspace/BrainAligning_retrieval/generation_metric_outputs/subject_averages.csv

# %% [markdown]
# # Radar 图

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

method_name_mapping = {
    "ATCNet": "ATCNet",
    "ATM": "ATM-S (Ours)",
    "EEGConformer": "Conformer",
    "EEGITNet": "EEGITNet",
    "EEGNetV4": "EEGNetV4",
    "MetaEEG": "B.D.",
    "NICE": "NICE." ,
    "Projector": "MLP" ,
    "ShallowFBCSPNet": "ShallowFBCSPNet" ,
    # Add more mappings as needed
    # "OriginalName": "NewName",
}

# Correct file paths for your CSV files
file_paths = [
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/insubject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/cross_subject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/insubject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/cross_subject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/generation_metric_outputs/subject_averages.csv'
]

def load_and_normalize_data(file_paths):
    dfs = []
    for fp in file_paths:
        try:
            df = pd.read_csv(fp)
            if 'Method' not in df.columns or 'Test Accuracy' not in df.columns:
                print(f"Warning: 'Method' or 'Test Accuracy' column not found in {fp}")
                continue
            if df.empty:
                print(f"Warning: No data found in {fp}")
                continue
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {fp}: {e}")
            continue

    if not dfs:
        raise ValueError("No valid data found from the file paths provided.")

    all_methods = set().union(*(set(df['Method']) for df in dfs))
    
    # Normalize the values by the maximum value for each method across all conditions
    values_dict = {method: [] for method in all_methods}
    for df in dfs:
        max_value = df['Test Accuracy'].max()
        for method in all_methods:
            if method in df['Method'].values:
                test_accuracy = df.loc[df['Method'] == method, 'Test Accuracy'].values[0]
            else:
                test_accuracy = 0.01  # small non-zero value for missing data
            values_dict[method].append(test_accuracy / max_value)

    methods = sorted(all_methods)  # Sort methods alphabetically
    normalized_values = np.array([values_dict[method] for method in methods])

    return methods, normalized_values

methods, normalized_values = load_and_normalize_data(file_paths)

# Print out method names and corresponding normalized values for verification
for method, values in zip(methods, normalized_values):
    print(f"{method}: {values}")

labels = ['Cls (in)', 'Cls (cross)', 'Ret (in)', 'Ret (cross)', 'Gen']
n_labels = len(labels)
angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()
angles += angles[:1]  # Complete the loop for the radar chart
# ... (rest of your code remains unchanged)
# Out:
# ATCNet: [0.11049724 0.22727273 0.05203252 0.10926366 0.02785515]
# ATM: [1. 1. 1. 1. 1.]
# EEGConformer: [0.22099448 0.29545455 0.1495935  0.21852732 0.02785515]
# EEGITNet: [0.11049724 0.22727273 0.19674797 0.25296912 0.02785515]
# EEGNetv4: [0.3038674  0.5        0.73495935 0.52731591 0.53203343]
# MetaEEG: [0.11049724 0.22727273 0.34146341 0.88361045 0.1545961 ]
# NICE: [0.63535912 0.71590909 0.7398374  0.55106888 0.57799443]
# Projector: [0.11049724 0.22727273 0.33658537 0.4584323  0.02785515]
# ShallowFBCSPNet: [0.10497238 0.25       0.22113821 0.15914489 0.02785515]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


def find_max_per_category(normalized_values):
    """
    Find the index of the method with the maximum value for each category.
    """
    # Transpose to get categories as rows for easier max value identification
    transposed_values = normalized_values.transpose()
    max_indices = np.argmax(transposed_values, axis=1)
    return max_indices

# Determine the max value per category
max_indices = find_max_per_category(normalized_values)

# Prepare the radar chart
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
plt.xticks(angles[:-1], labels, color='black', size=12)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20","40","60","80","100"], color="grey", size=14)
plt.ylim(0,1)
ax.tick_params(axis='x', which='major', pad=15)  # Increase pad value to move xticks further out

for i, method in enumerate(methods):
    values = normalized_values[i].tolist()
    values += values[:1]  # Ensure the loop closes properly
    display_name = method_name_mapping.get(method, method)
    ax.plot(angles, values, linewidth=2.5, linestyle='solid', label=display_name)
    ax.fill(angles, values, alpha=0.1)
# Define a list of bright colors for the lines
# bright_colors = [ '#3357FF', '#F833FF', '#33FFF8', '#F8FF33', '#FF3357', '#57FF33', '#FF8333', '#FF5733', '#33FF57']

# for i, method in enumerate(methods):
#     values = normalized_values[i].tolist()
#     values += values[:1]  # Ensure the loop closes properly
#     display_name = method_name_mapping.get(method, method)
#     # Use modulo to cycle through the color list if there are more methods than colors
#     line_color = bright_colors[i % len(bright_colors)]
#     ax.plot(angles, values, linewidth=2.5, linestyle='solid', label=display_name, color=line_color)
#     ax.fill(angles, values, alpha=0.0, color=line_color)
    
# Adjust title and legend placement
# plt.title('Test Accuracy Comparison for All Methods', size=20, color='black', y=1.1)
lgd = ax.legend(loc='center left', bbox_to_anchor=(1.2, 0.5))
# Save and show the plot
plt.savefig('../plots/radar_chart_high_res.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties
method_name_mapping = {
    "ATCNet": "ATCNet",
    "ATM": "ATM-S (Ours)",
    "EEGConformer": "Conformer",
    "EEGITNet": "EEGITNet",
    "EEGNetv4": "EEGNetV4",
    "MetaEEG": "B.D.",
    "NICE": "NICE." ,
    "Projector": "MLP" ,
    "ShallowFBCSPNet": "ShallowFBCSPNet" ,
    # Add more mappings as needed
    # "OriginalName": "NewName",
}
method_colors = {
    "ATCNet": "#1f77b4",
    "ATM": "#ff7f0e",
    "EEGConformer": "#2ca02c",
    "EEGITNet": "#d62728",
    "EEGNetV4": "#9467bd",
    "B.D.": "#8c564b",
    "NICE.": "#e377c2",
    "MLP": "#7f7f7f",
    "ShallowFBCSPNet": "#bcbd22",
}
# Correct file paths for your CSV files
file_paths = [
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/insubject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/cross_subject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/insubject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/cross_subject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/generation_metric_outputs/subject_averages.csv'
]

def load_and_normalize_data(file_paths):
    dfs = []
    for fp in file_paths:
        try:
            df = pd.read_csv(fp)
            if 'Method' not in df.columns or 'Test Accuracy' not in df.columns or 'Top5 Accuracy' not in df.columns:
                print(f"Warning: 'Method', 'Test Accuracy' or 'Top5 Accuracy' column not found in {fp}")
                continue
            if df.empty:
                print(f"Warning: No data found in {fp}")
                continue
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {fp}: {e}")
            continue

    if not dfs:
        raise ValueError("No valid data found from the file paths provided.")

    all_methods = set().union(*(set(df['Method']) for df in dfs))

    # Normalize the values by the maximum value for each method across all conditions
    accuracy_dict = {method: [] for method in all_methods}
    top5_accuracy_dict = {method: [] for method in all_methods}
    
    for df in dfs:
        max_test_accuracy = df['Test Accuracy'].max()
        max_top5_accuracy = df['Top5 Accuracy'].max()
        
        for method in all_methods:
            if method in df['Method'].values:
                test_accuracy = df.loc[df['Method'] == method, 'Test Accuracy'].values[0]
                top5_accuracy = df.loc[df['Method'] == method, 'Top5 Accuracy'].values[0]
            else:
                test_accuracy = 0.01  # small non-zero value for missing data
                top5_accuracy = 0.01  # small non-zero value for missing data
            
            accuracy_dict[method].append(test_accuracy / max_test_accuracy)
            top5_accuracy_dict[method].append(top5_accuracy / max_top5_accuracy)

    methods = sorted(all_methods)
    normalized_values = np.array([accuracy_dict[method] + top5_accuracy_dict[method] for method in methods])

    return methods, normalized_values

# Assuming file_paths is defined elsewhere and contains the paths to your CSV files
methods, normalized_values = load_and_normalize_data(file_paths)
print("methods", methods)
print("normalized_values", normalized_values)

labels = ['Cls (in)', 'Cls (in) Top5', 'Cls (cross)', 'Cls (cross) Top5', 
          'Ret (in)', 'Ret (in) Top5', 'Ret (cross)', 'Ret (cross) Top5', 
          'Gen', 'Gen Top5']
n_labels = len(labels)

angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_xticklabels([])

ax.set_rlabel_position(0)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20%", "40%", "60%", "80%", "100%"], color="grey", size=7)
plt.ylim(0, 1)
# Create a font properties object for the legend font
legend_font = FontProperties(family='Times New Roman', size=12)
max_values = np.max(normalized_values, axis=1)
max_method_index = np.argmax(max_values)

for values, method in zip(normalized_values, methods):
    if len(values) < n_labels:
        values = np.append(values, [0]*(n_labels - len(values)))
    linewidth = 3 if method == 'ATM' else 1
    ax.plot(angles, values, linewidth=linewidth, linestyle='solid', label=method_name_mapping[method])
    ax.fill(angles, values, alpha=0.25)

# plt.title('Method Performance Comparison', size=20, color='black', y=1.1)
legend = ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.4), frameon=False, ncol=len(methods)//2)
for text in legend.get_texts():
    text.set_fontproperties(legend_font)
# Adjust the bounding box to include the legend when saving
plt.savefig("../plots/radar_eeg.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.font_manager import FontProperties
methods, normalized_values = load_and_normalize_data(file_paths)

# Define labels for each 'Test Accuracy' and 'Top5 Accuracy' point
labels = ['Cls (in)', 'Cls (in) Top5', 'Cls (cross)', 'Cls (cross) Top5', 
          'Ret (in)', 'Ret (in) Top5', 'Ret (cross)', 'Ret (cross) Top5', 
          'Gen', 'Gen Top5']
n_labels = len(labels)

# Create angles for the radar chart
angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_xticklabels([])  # Remove the angle labels

# Set up the radial axis and its labels
ax.set_rlabel_position(0)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20%", "40%", "60%", "80%", "100%"], color="grey", size=7)
plt.ylim(0, 1)

# Create a font properties object for the legend font
legend_font = FontProperties(family='Times New Roman', size=12)

# Plot the data and fill with color
for index, (values, method) in enumerate(zip(normalized_values, methods)):
    values = np.append(values, values[0])  # Close the loop
    # Set a thicker line width for "ATM-S (Ours)"
    linewidth = 3 if method == 'ATM' else 1
    label = method_name_mapping.get(method, method)  # Get the display name for the method
    color = method_colors.get(method, '#333')  # Get the color for the method
    ax.plot(angles, values, color=color, linewidth=linewidth, linestyle='solid', label=label)
    ax.fill(angles, values, color=color, alpha=0.25)

# Set legend at the bottom without a frame and using the specified font
legend = ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=3)
for text in legend.get_texts():
    text.set_fontproperties(legend_font)

# Display the plot
plt.show()
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

method_name_mapping = {
    "ATCNet": "ATCNet",
    "ATM": "ATM-S (Ours)",
    "EEGConformer": "Conformer",
    "EEGITNet": "EEGITNet",
    "EEGNetV4": "EEGNetV4",
    "MetaEEG": "B.D.",
    "NICE": "NICE." ,
    "Projector": "MLP" ,
    "ShallowFBCSPNet": "ShallowFBCSPNet" ,
    # Add more mappings as needed
    # "OriginalName": "NewName",
}
method_colors = {
    "ATCNet": "#1f77b4",
    "ATM": "#ff7f0e",
    "EEGConformer": "#2ca02c",
    "EEGITNet": "#d62728",
    "EEGNetV4": "#9467bd",
    "B.D.": "#8c564b",
    "NICE.": "#e377c2",
    "MLP": "#7f7f7f",
    "ShallowFBCSPNet": "#bcbd22",
}
# Correct file paths for your CSV files
file_paths = [
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/insubject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Classification/cross_subject/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/insubject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/Outputs/EEG_radar_graph1/Retrieval/cross_subject/batchsize=1024/subject_averages.csv',
    '/home/ldy/Workspace/BrainAligning_retrieval/generation_metric_outputs/subject_averages.csv'
]

def load_and_normalize_data(file_paths):
    dfs = []
    for fp in file_paths:
        try:
            df = pd.read_csv(fp)
            if 'Method' not in df.columns or 'Test Accuracy' not in df.columns or 'Top5 Accuracy' not in df.columns:
                print(f"Warning: 'Method', 'Test Accuracy' or 'Top5 Accuracy' column not found in {fp}")
                continue
            if df.empty:
                print(f"Warning: No data found in {fp}")
                continue
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {fp}: {e}")
            continue

    if not dfs:
        raise ValueError("No valid data found from the file paths provided.")

    all_methods = set().union(*(set(df['Method']) for df in dfs))

    # Normalize the values by the maximum value for each method across all conditions
    accuracy_dict = {method: [] for method in all_methods}
    top5_accuracy_dict = {method: [] for method in all_methods}
    
    for df in dfs:
        max_test_accuracy = df['Test Accuracy'].max()
        max_top5_accuracy = df['Top5 Accuracy'].max()
        
        for method in all_methods:
            if method in df['Method'].values:
                test_accuracy = df.loc[df['Method'] == method, 'Test Accuracy'].values[0]
                top5_accuracy = df.loc[df['Method'] == method, 'Top5 Accuracy'].values[0]
            else:
                test_accuracy = 0.01  # small non-zero value for missing data
                top5_accuracy = 0.01  # small non-zero value for missing data
            
            accuracy_dict[method].append(test_accuracy / max_test_accuracy)
            top5_accuracy_dict[method].append(top5_accuracy / max_top5_accuracy)

    methods = sorted(all_methods)
    normalized_values = np.array([accuracy_dict[method] + top5_accuracy_dict[method] for method in methods])

    return methods, normalized_values

methods, normalized_values = load_and_normalize_data(file_paths)

# Define labels for each 'Test Accuracy' and 'Top5 Accuracy' point
labels = ['Cls (in)', 'Cls (in) Top5', 'Cls (cross)', 'Cls (cross) Top5', 
          'Ret (in)', 'Ret (in) Top5', 'Ret (cross)', 'Ret (cross) Top5', 
          'Gen', 'Gen Top5']
n_labels = len(labels)

# Create angles for the radar chart
angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_xticklabels([])  # Remove the angle labels

# Set up the radial axis and its labels
ax.set_rlabel_position(0)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20%", "40%", "60%", "80%", "100%"], color="grey", size=7)
plt.ylim(0, 1)

# Plot the data and fill with color
for index, (values, method) in enumerate(zip(normalized_values, methods)):
    values = np.append(values, values[0])  # Close the loop
    # Set a thicker line width for "ATM-S (Ours)"
    linewidth = 4 if method == 'ATM' else 1
    color = method_colors.get(method, '#333333')  # Default color if not found
    label = method_name_mapping.get(method, method)  # Default to method name if not found
    ax.plot(angles, values, linewidth=linewidth, linestyle='solid', label=label, color=color)
    ax.fill(angles, values, alpha=0.25, color=color)

# Set legend at the bottom without a frame
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=3)

# Display the plot
plt.show()

# %%
methods, normalized_values = load_and_normalize_data(file_paths)

# Define labels for each 'Test Accuracy' and 'Top5 Accuracy' point
labels = ['Cls (in)', 'Cls (in) Top5', 'Cls (cross)', 'Cls (cross) Top5', 
          'Ret (in)', 'Ret (in) Top5', 'Ret (cross)', 'Ret (cross) Top5', 
          'Gen', 'Gen Top5']
n_labels = len(labels)

# Create angles for the radar chart
angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_xticklabels([])  # Remove the angle labels

# Set up the radial axis and its labels
ax.set_rlabel_position(0)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20%", "40%", "60%", "80%", "100%"], color="grey", size=7)
plt.ylim(0, 1)

# Plot the data and fill with color
for index, (values, method) in enumerate(zip(normalized_values, methods)):
    values = np.append(values, values[0])  # Close the loop
    # Set a thicker line width for "ATM-S (Ours)" and get the color for the method
    linewidth = 4 if method == 'ATM' else 1
    color = method_colors[method]  # Get the color for the method
    label = method_name_mapping[method]  # Get the display name for the method
    ax.plot(angles, values, linewidth=linewidth, linestyle='solid', label=label, color=color)
    ax.fill(angles, values, alpha=0.25, color=color)

# Set legend at the bottom without a frame
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=3)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 26
#      24 # Set a thicker line width for "ATM-S (Ours)" and get the color for the method
#      25 linewidth = 4 if method == 'ATM' else 1
# ---> 26 color = method_colors[method]  # Get the color for the method
#      27 label = method_name_mapping[method]  # Get the display name for the method
#      28 ax.plot(angles, values, linewidth=linewidth, linestyle='solid', label=label, color=color)
#
# KeyError: 'EEGNetv4'

# %%
def load_data(file_paths):
    dfs = []
    for fp in file_paths:
        try:
            df = pd.read_csv(fp)
            if 'Method' not in df.columns or 'Test Accuracy' not in df.columns or 'Top5 Accuracy' not in df.columns:
                print(f"Warning: 'Method', 'Test Accuracy' or 'Top5 Accuracy' column not found in {fp}")
                continue
            if df.empty:
                print(f"Warning: No data found in {fp}")
                continue
            dfs.append(df)
        except Exception as e:
            print(f"Error reading {fp}: {e}")
            continue

    if not dfs:
        raise ValueError("No valid data found from the file paths provided.")

    all_methods = set().union(*(set(df['Method']) for df in dfs))
    
    accuracy_values = {method: [] for method in all_methods}
    top5_accuracy_values = {method: [] for method in all_methods}
    
    for df in dfs:
        for method in all_methods:
            if method in df['Method'].values:
                test_accuracy = df.loc[df['Method'] == method, 'Test Accuracy'].values[0]
                top5_accuracy = df.loc[df['Method'] == method, 'Top5 Accuracy'].values[0]
            else:
                test_accuracy = 0  # use zero for missing data
                top5_accuracy = 0  # use zero for missing data
            
            accuracy_values[method].append(test_accuracy)
            top5_accuracy_values[method].append(top5_accuracy)

    methods = sorted(all_methods)
    absolute_values = np.array([accuracy_values[method] + top5_accuracy_values[method] for method in methods])

    return methods, absolute_values

methods, absolute_values = load_data(file_paths)

# Define labels for each 'Test Accuracy' and 'Top5 Accuracy' point
labels = ['Cls (in)', 'Cls (in) Top5', 'Cls (cross)', 'Cls (cross) Top5', 
          'Ret (in)', 'Ret (in) Top5', 'Ret (cross)', 'Ret (cross) Top5', 
          'Gen', 'Gen Top5']
n_labels = len(labels)

# Create angles for the radar chart
angles = np.linspace(0, 2 * np.pi, n_labels, endpoint=False).tolist()
angles += angles[:1]  # Close the loop

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.set_xticklabels([])  # Remove the angle labels

# Set up the radial axis and its labels
ax.set_rlabel_position(0)
plt.yticks([0.2, 0.4, 0.6, 0.8, 1], ["20%", "40%", "60%", "80%", "100%"], color="grey", size=7)
plt.ylim(0, 1)

# Plot the data and fill with color
for index, (values, method) in enumerate(zip(absolute_values, methods)):
    values = np.append(values, values[0])  # Close the loop
    # Determine the line width based on whether it's the method with the maximum value
    linewidth = 4 if index == np.argmax([max(v) for v in absolute_values]) else 1
    # Use the color and name from the mappings
    color = method_colors.get(method, '#333333')  # Default color if not found
    label = method_name_mapping.get(method, method)  # Default to method name if not found
    ax.plot(angles, values, linewidth=linewidth, linestyle='solid', label=label, color=color)
    ax.fill(angles, values, alpha=0.25, color=color)

# Set legend at the bottom without a frame
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), frameon=False, ncol=3)

# Display the plot
plt.show()
