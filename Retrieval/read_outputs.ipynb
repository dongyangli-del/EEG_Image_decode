# %%
import os
import pandas as pd

# Directory path containing the CSV files
directory_path = 'outputs'

# Function to calculate the averages of the last 10 epochs
def calculate_averages(file_path):
    df = pd.read_csv(file_path)
    last_10_epochs = df.tail(10)
    averages = {
        'v2_acc': last_10_epochs['v2_acc'].mean(),
        'v4_acc': last_10_epochs['v4_acc'].mean(),
        'v10_acc': last_10_epochs['v10_acc'].mean(),
        'test_accuracy': last_10_epochs['test_accuracy'].mean(),  # TOP1 accuracy
        'top5_acc': last_10_epochs['top5_acc'].mean()  # TOP5 accuracy
    }
    return averages

# Dictionary to store the results
results = {}

# Iterate over each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        results[filename] = calculate_averages(file_path)

# Sort the results by model (filename)
sorted_results = dict(sorted(results.items()))

# Display the results
for model, averages in sorted_results.items():
    print(f"Model: {model}")
    for metric, value in averages.items():
        # Convert to percentage and format with 2 decimal places
        formatted_value = "{:.2f}".format(value * 100)
        print(f"{metric}: {formatted_value}")
    print()
# Out:
# Model: ATCNet_Encoder_cross_exclude_sub-01.csv
# v2_acc: 65.85
# v4_acc: 42.25
# v10_acc: 20.40
# test_accuracy: 1.00
# top5_acc: 5.60
#
# Model: ATCNet_Encoder_cross_exclude_sub-02.csv
# v2_acc: 68.75
# v4_acc: 43.80
# v10_acc: 23.05
# test_accuracy: 2.00
# top5_acc: 7.20
#
# Model: ATCNet_Encoder_cross_exclude_sub-03.csv
# v2_acc: 66.80
# v4_acc: 41.55
# v10_acc: 20.85
# test_accuracy: 0.60
# top5_acc: 6.35
#
# Model: ATCNet_Encoder_cross_exclude_sub-04.csv
# v2_acc: 72.05
# v4_acc: 47.65
# v10_acc: 25.70
# test_accuracy: 1.90
# top5_acc: 9.15
#
# Model: ATCNet_Encoder_cross_exclude_sub-05.csv
# v2_acc: 64.70
# v4_acc: 39.15
# v10_acc: 19.60
# test_accuracy: 1.25
# top5_acc: 6.00
#
# Model: ATCNet_Encoder_cross_exclude_sub-06.csv
# v2_acc: 72.70
# v4_acc: 50.70
# v10_acc: 28.70
# test_accuracy: 2.30
# top5_acc: 10.90
#
# Model: ATCNet_Encoder_cross_exclude_sub-07.csv
# v2_acc: 71.80
# v4_acc: 49.20
# v10_acc: 29.25
# test_accuracy: 2.55
# top5_acc: 10.50
#
# Model: ATCNet_Encoder_cross_exclude_sub-08.csv
# v2_acc: 70.30
# v4_acc: 48.30
# v10_acc: 25.05
# test_accuracy: 2.10
# top5_acc: 10.40
#
# Model: ATCNet_Encoder_cross_exclude_sub-09.csv
# v2_acc: 69.40
# v4_acc: 44.20
# v10_acc: 20.55
# test_accuracy: 1.45
# top5_acc: 5.95
#
# Model: ATCNet_Encoder_cross_exclude_sub-10.csv
# v2_acc: 75.70
# v4_acc: 52.35
# v10_acc: 32.70
# test_accuracy: 2.20
# top5_acc: 12.40
#
# Model: EEGITNet_Encoder_cross_exclude_sub-01.csv
# v2_acc: 78.35
# v4_acc: 57.85
# v10_acc: 34.35
# test_accuracy: 4.45
# top5_acc: 13.95
#
# Model: EEGITNet_Encoder_cross_exclude_sub-02.csv
# v2_acc: 79.30
# v4_acc: 59.60
# v10_acc: 35.30
# test_accuracy: 4.70
# top5_acc: 15.20
#
# Model: EEGITNet_Encoder_cross_exclude_sub-03.csv
# v2_acc: 76.05
# v4_acc: 52.40
# v10_acc: 30.85
# test_accuracy: 1.50
# top5_acc: 12.05
#
# Model: EEGITNet_Encoder_cross_exclude_sub-04.csv
# v2_acc: 81.20
# v4_acc: 58.55
# v10_acc: 36.90
# test_accuracy: 4.80
# top5_acc: 14.40
#
# Model: EEGITNet_Encoder_cross_exclude_sub-05.csv
# v2_acc: 71.55
# v4_acc: 46.20
# v10_acc: 25.20
# test_accuracy: 1.00
# top5_acc: 8.60
#
# Model: EEGITNet_Encoder_cross_exclude_sub-06.csv
# v2_acc: 78.75
# v4_acc: 59.60
# v10_acc: 37.70
# test_accuracy: 5.50
# top5_acc: 17.45
#
# Model: EEGITNet_Encoder_cross_exclude_sub-07.csv
# v2_acc: 76.55
# v4_acc: 55.25
# v10_acc: 33.30
# test_accuracy: 4.50
# top5_acc: 13.35
#
# Model: EEGITNet_Encoder_cross_exclude_sub-08.csv
# v2_acc: 78.45
# v4_acc: 56.10
# v10_acc: 33.00
# test_accuracy: 3.70
# top5_acc: 14.25
#
# Model: EEGITNet_Encoder_cross_exclude_sub-09.csv
# v2_acc: 71.45
# v4_acc: 46.50
# v10_acc: 24.00
# test_accuracy: 1.00
# top5_acc: 8.95
#
# Model: EEGITNet_Encoder_cross_exclude_sub-10.csv
# v2_acc: 83.10
# v4_acc: 65.50
# v10_acc: 45.40
# test_accuracy: 6.90
# top5_acc: 22.00
#
# Model: MetaEEG_cross_exclude_sub-01.csv
# v2_acc: 83.05
# v4_acc: 62.20
# v10_acc: 42.60
# test_accuracy: 6.55
# top5_acc: 21.45
#
# Model: MetaEEG_cross_exclude_sub-02.csv
# v2_acc: 76.85
# v4_acc: 57.45
# v10_acc: 33.95
# test_accuracy: 5.00
# top5_acc: 16.40
#
# Model: MetaEEG_cross_exclude_sub-03.csv
# v2_acc: 80.75
# v4_acc: 61.70
# v10_acc: 36.90
# test_accuracy: 5.45
# top5_acc: 17.00
#
# Model: MetaEEG_cross_exclude_sub-04.csv
# v2_acc: 82.75
# v4_acc: 64.10
# v10_acc: 42.65
# test_accuracy: 6.65
# top5_acc: 22.35
#
# Model: MetaEEG_cross_exclude_sub-05.csv
# v2_acc: 77.35
# v4_acc: 54.65
# v10_acc: 33.15
# test_accuracy: 3.10
# top5_acc: 14.75
#
# Model: MetaEEG_cross_exclude_sub-06.csv
# v2_acc: 85.20
# v4_acc: 71.15
# v10_acc: 49.65
# test_accuracy: 9.95
# top5_acc: 29.20
#
# Model: MetaEEG_cross_exclude_sub-07.csv
# v2_acc: 84.55
# v4_acc: 69.30
# v10_acc: 46.20
# test_accuracy: 6.45
# top5_acc: 24.00
#
# Model: MetaEEG_cross_exclude_sub-08.csv
# v2_acc: 82.95
# v4_acc: 61.10
# v10_acc: 40.40
# test_accuracy: 6.00
# top5_acc: 19.35
#
# Model: MetaEEG_cross_exclude_sub-09.csv
# v2_acc: 76.15
# v4_acc: 52.10
# v10_acc: 29.20
# test_accuracy: 2.60
# top5_acc: 12.75
#
# Model: MetaEEG_cross_exclude_sub-10.csv
# v2_acc: 85.30
# v4_acc: 69.70
# v10_acc: 50.60
# test_accuracy: 9.80
# top5_acc: 27.30
#
# Model: MetaEEG_sub-01.csv
# v2_acc: 90.70
# v4_acc: 77.35
# v10_acc: 56.55
# test_accuracy: 13.05
# top5_acc: 36.00
#
# Model: MetaEEG_sub-02.csv
# v2_acc: 89.50
# v4_acc: 76.25
# v10_acc: 59.70
# test_accuracy: 13.35
# top5_acc: 38.00
#
# Model: MetaEEG_sub-03.csv
# v2_acc: 90.85
# v4_acc: 77.45
# v10_acc: 61.60
# test_accuracy: 14.45
# top5_acc: 37.85
#
# Model: MetaEEG_sub-04.csv
# v2_acc: 93.15
# v4_acc: 83.30
# v10_acc: 66.20
# test_accuracy: 17.45
# top5_acc: 45.00
#
# Model: MetaEEG_sub-05.csv
# v2_acc: 86.50
# v4_acc: 72.95
# v10_acc: 53.20
# test_accuracy: 10.55
# top5_acc: 32.00
#
# Model: MetaEEG_sub-06.csv
# v2_acc: 90.80
# v4_acc: 78.60
# v10_acc: 60.00
# test_accuracy: 14.25
# top5_acc: 40.35
#
# Model: MetaEEG_sub-07.csv
# v2_acc: 92.70
# v4_acc: 80.55
# v10_acc: 65.15
# test_accuracy: 18.65
# top5_acc: 46.80
#
# Model: MetaEEG_sub-08.csv
# v2_acc: 94.30
# v4_acc: 87.55
# v10_acc: 72.70
# test_accuracy: 24.50
# top5_acc: 54.65
#
# Model: MetaEEG_sub-09.csv
# v2_acc: 88.90
# v4_acc: 76.40
# v10_acc: 59.15
# test_accuracy: 14.60
# top5_acc: 37.55
#
# Model: MetaEEG_sub-10.csv
# v2_acc: 93.95
# v4_acc: 85.55
# v10_acc: 71.90
# test_accuracy: 22.10
# top5_acc: 53.45
#
# Model: NICE1_cross_exclude_sub-01.csv
# v2_acc: 81.30
# v4_acc: 61.80
# v10_acc: 41.00
# test_accuracy: 8.30
# top5_acc: 25.50
#
# Model: NICE1_cross_exclude_sub-02.csv
# v2_acc: 82.45
# v4_acc: 65.45
# v10_acc: 44.45
# test_accuracy: 7.25
# top5_acc: 23.65
#
# Model: NICE1_cross_exclude_sub-03.csv
# v2_acc: 88.70
# v4_acc: 74.65
# v10_acc: 56.95
# test_accuracy: 11.40
# top5_acc: 31.30
#
# Model: NICE1_cross_exclude_sub-04.csv
# v2_acc: 91.05
# v4_acc: 78.35
# v10_acc: 61.25
# test_accuracy: 14.55
# top5_acc: 39.80
#
# Model: NICE1_cross_exclude_sub-05.csv
# v2_acc: 84.85
# v4_acc: 67.20
# v10_acc: 43.75
# test_accuracy: 5.95
# top5_acc: 21.25
#
# Model: NICE1_cross_exclude_sub-06.csv
# v2_acc: 85.70
# v4_acc: 69.90
# v10_acc: 50.50
# test_accuracy: 9.45
# top5_acc: 30.95
#
# Model: NICE1_cross_exclude_sub-07.csv
# v2_acc: 79.85
# v4_acc: 58.80
# v10_acc: 39.35
# test_accuracy: 4.80
# top5_acc: 19.45
#
# Model: NICE1_cross_exclude_sub-08.csv
# v2_acc: 77.35
# v4_acc: 54.25
# v10_acc: 32.20
# test_accuracy: 4.85
# top5_acc: 14.00
#
# Model: NICE1_cross_exclude_sub-09.csv
# v2_acc: 73.65
# v4_acc: 51.70
# v10_acc: 30.50
# test_accuracy: 4.05
# top5_acc: 13.30
#
# Model: NICE1_cross_exclude_sub-10.csv
# v2_acc: 83.95
# v4_acc: 68.20
# v10_acc: 48.60
# test_accuracy: 9.75
# top5_acc: 26.95
#
# Model: NICE1_sub-01.csv
# v2_acc: 93.85
# v4_acc: 85.10
# v10_acc: 70.40
# test_accuracy: 19.10
# top5_acc: 49.05
#
# Model: NICE1_sub-02.csv
# v2_acc: 90.50
# v4_acc: 81.50
# v10_acc: 63.80
# test_accuracy: 15.10
# top5_acc: 41.00
#
# Model: NICE1_sub-03.csv
# v2_acc: 95.10
# v4_acc: 88.70
# v10_acc: 75.40
# test_accuracy: 22.95
# top5_acc: 56.30
#
# Model: NICE1_sub-04.csv
# v2_acc: 95.70
# v4_acc: 88.20
# v10_acc: 74.30
# test_accuracy: 25.75
# top5_acc: 55.75
#
# Model: NICE1_sub-05.csv
# v2_acc: 90.50
# v4_acc: 77.10
# v10_acc: 61.15
# test_accuracy: 16.10
# top5_acc: 39.95
#
# Model: NICE1_sub-06.csv
# v2_acc: 94.00
# v4_acc: 84.80
# v10_acc: 70.20
# test_accuracy: 20.05
# top5_acc: 50.10
#
# Model: NICE1_sub-07.csv
# v2_acc: 94.85
# v4_acc: 86.80
# v10_acc: 74.75
# test_accuracy: 25.75
# top5_acc: 55.40
#
# Model: NICE1_sub-08.csv
# v2_acc: 96.00
# v4_acc: 90.55
# v10_acc: 82.05
# test_accuracy: 34.90
# top5_acc: 67.50
#
# Model: NICE1_sub-09.csv
# v2_acc: 93.30
# v4_acc: 83.50
# v10_acc: 68.40
# test_accuracy: 21.50
# top5_acc: 48.15
#
# Model: NICE1_sub-10.csv
# v2_acc: 95.10
# v4_acc: 87.60
# v10_acc: 75.85
# test_accuracy: 27.15
# top5_acc: 58.95
#
# Model: NICE2_cross_exclude_sub-01.csv
# v2_acc: 83.80
# v4_acc: 67.35
# v10_acc: 43.00
# test_accuracy: 7.80
# top5_acc: 22.95
#
# Model: NICE2_cross_exclude_sub-02.csv
# v2_acc: 85.65
# v4_acc: 71.45
# v10_acc: 50.00
# test_accuracy: 8.65
# top5_acc: 27.60
#
# Model: NICE2_cross_exclude_sub-03.csv
# v2_acc: 88.50
# v4_acc: 76.85
# v10_acc: 57.15
# test_accuracy: 13.75
# top5_acc: 35.70
#
# Model: NICE2_cross_exclude_sub-04.csv
# v2_acc: 84.35
# v4_acc: 66.20
# v10_acc: 45.90
# test_accuracy: 7.45
# top5_acc: 24.10
#
# Model: NICE2_cross_exclude_sub-05.csv
# v2_acc: 77.35
# v4_acc: 57.30
# v10_acc: 34.50
# test_accuracy: 4.20
# top5_acc: 14.30
#
# Model: NICE2_cross_exclude_sub-06.csv
# v2_acc: 84.55
# v4_acc: 69.80
# v10_acc: 48.40
# test_accuracy: 7.70
# top5_acc: 26.80
#
# Model: NICE2_cross_exclude_sub-07.csv
# v2_acc: 86.25
# v4_acc: 65.90
# v10_acc: 47.55
# test_accuracy: 6.40
# top5_acc: 25.95
#
# Model: NICE2_cross_exclude_sub-08.csv
# v2_acc: 79.35
# v4_acc: 59.40
# v10_acc: 36.70
# test_accuracy: 4.85
# top5_acc: 16.25
#
# Model: NICE2_cross_exclude_sub-09.csv
# v2_acc: 77.25
# v4_acc: 54.05
# v10_acc: 33.75
# test_accuracy: 4.50
# top5_acc: 14.90
#
# Model: NICE2_cross_exclude_sub-10.csv
# v2_acc: 85.90
# v4_acc: 69.65
# v10_acc: 51.45
# test_accuracy: 9.45
# top5_acc: 28.90
#
# Model: NICE2_sub-01.csv
# v2_acc: 93.65
# v4_acc: 84.35
# v10_acc: 68.15
# test_accuracy: 20.75
# top5_acc: 47.35
#
# Model: NICE2_sub-02.csv
# v2_acc: 92.90
# v4_acc: 82.35
# v10_acc: 65.40
# test_accuracy: 15.25
# top5_acc: 44.90
#
# Model: NICE2_sub-03.csv
# v2_acc: 94.50
# v4_acc: 86.90
# v10_acc: 71.25
# test_accuracy: 25.10
# top5_acc: 56.45
#
# Model: NICE2_sub-04.csv
# v2_acc: 95.30
# v4_acc: 88.00
# v10_acc: 74.55
# test_accuracy: 24.05
# top5_acc: 53.95
#
# Model: NICE2_sub-05.csv
# v2_acc: 91.90
# v4_acc: 80.95
# v10_acc: 64.35
# test_accuracy: 18.50
# top5_acc: 44.35
#
# Model: NICE2_sub-06.csv
# v2_acc: 94.75
# v4_acc: 87.50
# v10_acc: 73.95
# test_accuracy: 23.00
# top5_acc: 53.95
#
# Model: NICE2_sub-07.csv
# v2_acc: 95.30
# v4_acc: 87.20
# v10_acc: 72.20
# test_accuracy: 24.70
# top5_acc: 54.10
#
# Model: NICE2_sub-08.csv
# v2_acc: 97.70
# v4_acc: 92.40
# v10_acc: 82.20
# test_accuracy: 39.40
# top5_acc: 70.25
#
# Model: NICE2_sub-09.csv
# v2_acc: 92.45
# v4_acc: 83.25
# v10_acc: 68.35
# test_accuracy: 23.40
# top5_acc: 52.40
#
# Model: NICE2_sub-10.csv
# v2_acc: 95.90
# v4_acc: 88.25
# v10_acc: 78.45
# test_accuracy: 29.60
# top5_acc: 63.75
#
# Model: NICE3_cross_exclude_sub-01.csv
# v2_acc: 84.65
# v4_acc: 65.80
# v10_acc: 46.05
# test_accuracy: 10.45
# top5_acc: 26.75
#
# Model: NICE3_cross_exclude_sub-02.csv
# v2_acc: 83.05
# v4_acc: 68.20
# v10_acc: 48.10
# test_accuracy: 7.10
# top5_acc: 24.75
#
# Model: NICE3_cross_exclude_sub-03.csv
# v2_acc: 88.95
# v4_acc: 74.00
# v10_acc: 54.10
# test_accuracy: 11.85
# top5_acc: 33.80
#
# Model: NICE3_cross_exclude_sub-04.csv
# v2_acc: 89.95
# v4_acc: 77.00
# v10_acc: 59.90
# test_accuracy: 14.65
# top5_acc: 39.40
#
# Model: NICE3_cross_exclude_sub-05.csv
# v2_acc: 82.75
# v4_acc: 65.65
# v10_acc: 43.95
# test_accuracy: 6.95
# top5_acc: 23.85
#
# Model: NICE3_cross_exclude_sub-06.csv
# v2_acc: 86.85
# v4_acc: 73.60
# v10_acc: 53.80
# test_accuracy: 11.10
# top5_acc: 35.80
#
# Model: NICE3_cross_exclude_sub-07.csv
# v2_acc: 90.30
# v4_acc: 77.10
# v10_acc: 58.90
# test_accuracy: 16.05
# top5_acc: 43.50
#
# Model: NICE3_cross_exclude_sub-08.csv
# v2_acc: 91.65
# v4_acc: 80.60
# v10_acc: 61.50
# test_accuracy: 14.95
# top5_acc: 40.25
#
# Model: NICE3_cross_exclude_sub-09.csv
# v2_acc: 82.35
# v4_acc: 62.50
# v10_acc: 43.30
# test_accuracy: 4.85
# top5_acc: 22.70
#
# Model: NICE3_cross_exclude_sub-10.csv
# v2_acc: 93.10
# v4_acc: 83.60
# v10_acc: 68.45
# test_accuracy: 20.45
# top5_acc: 46.50
#
# Model: NICE3_sub-01.csv
# v2_acc: 95.10
# v4_acc: 87.30
# v10_acc: 74.85
# test_accuracy: 25.60
# top5_acc: 60.40
#
# Model: NICE3_sub-02.csv
# v2_acc: 94.50
# v4_acc: 87.00
# v10_acc: 70.45
# test_accuracy: 22.00
# top5_acc: 54.50
#
# Model: NICE3_sub-03.csv
# v2_acc: 96.50
# v4_acc: 88.30
# v10_acc: 76.85
# test_accuracy: 25.00
# top5_acc: 62.35
#
# Model: NICE3_sub-04.csv
# v2_acc: 95.25
# v4_acc: 89.25
# v10_acc: 76.80
# test_accuracy: 31.35
# top5_acc: 60.90
#
# Model: NICE3_sub-05.csv
# v2_acc: 89.60
# v4_acc: 76.55
# v10_acc: 60.55
# test_accuracy: 12.90
# top5_acc: 43.00
#
# Model: NICE3_sub-06.csv
# v2_acc: 94.50
# v4_acc: 85.40
# v10_acc: 71.60
# test_accuracy: 21.30
# top5_acc: 51.05
#
# Model: NICE3_sub-07.csv
# v2_acc: 94.65
# v4_acc: 88.95
# v10_acc: 76.65
# test_accuracy: 30.50
# top5_acc: 61.50
#
# Model: NICE3_sub-08.csv
# v2_acc: 96.35
# v4_acc: 92.00
# v10_acc: 83.15
# test_accuracy: 38.80
# top5_acc: 72.00
#
# Model: NICE3_sub-09.csv
# v2_acc: 93.95
# v4_acc: 84.60
# v10_acc: 71.75
# test_accuracy: 24.35
# top5_acc: 51.50
#
# Model: NICE3_sub-10.csv
# v2_acc: 95.55
# v4_acc: 89.40
# v10_acc: 76.30
# test_accuracy: 29.05
# top5_acc: 63.50
#
# Model: NICE4_cross_exclude_sub-01.csv
# v2_acc: 81.15
# v4_acc: 61.90
# v10_acc: 41.20
# test_accuracy: 7.35
# top5_acc: 21.45
#
# Model: NICE4_cross_exclude_sub-02.csv
# v2_acc: 86.25
# v4_acc: 69.45
# v10_acc: 48.10
# test_accuracy: 10.45
# top5_acc: 27.75
#
# Model: NICE4_cross_exclude_sub-03.csv
# v2_acc: 86.60
# v4_acc: 70.80
# v10_acc: 52.80
# test_accuracy: 9.60
# top5_acc: 30.55
#
# Model: NICE4_cross_exclude_sub-04.csv
# v2_acc: 90.10
# v4_acc: 77.85
# v10_acc: 57.20
# test_accuracy: 14.65
# top5_acc: 35.25
#
# Model: NICE4_cross_exclude_sub-05.csv
# v2_acc: 84.65
# v4_acc: 68.65
# v10_acc: 48.05
# test_accuracy: 7.40
# top5_acc: 24.75
#
# Model: NICE4_cross_exclude_sub-06.csv
# v2_acc: 88.80
# v4_acc: 74.25
# v10_acc: 54.15
# test_accuracy: 10.35
# top5_acc: 35.20
#
# Model: NICE4_cross_exclude_sub-07.csv
# v2_acc: 89.35
# v4_acc: 75.60
# v10_acc: 58.15
# test_accuracy: 14.05
# top5_acc: 39.05
#
# Model: NICE4_cross_exclude_sub-08.csv
# v2_acc: 91.10
# v4_acc: 79.85
# v10_acc: 61.65
# test_accuracy: 13.95
# top5_acc: 38.60
#
# Model: NICE4_cross_exclude_sub-09.csv
# v2_acc: 86.00
# v4_acc: 71.45
# v10_acc: 49.35
# test_accuracy: 7.55
# top5_acc: 30.65
#
# Model: NICE4_cross_exclude_sub-10.csv
# v2_acc: 90.15
# v4_acc: 78.70
# v10_acc: 60.85
# test_accuracy: 15.85
# top5_acc: 42.85
#
# Model: NICE4_sub-01.csv
# v2_acc: 89.60
# v4_acc: 79.35
# v10_acc: 62.55
# test_accuracy: 18.85
# top5_acc: 44.10
#
# Model: NICE4_sub-02.csv
# v2_acc: 91.40
# v4_acc: 80.40
# v10_acc: 63.55
# test_accuracy: 17.00
# top5_acc: 44.85
#
# Model: NICE4_sub-03.csv
# v2_acc: 94.30
# v4_acc: 87.95
# v10_acc: 74.70
# test_accuracy: 24.30
# top5_acc: 56.10
#
# Model: NICE4_sub-04.csv
# v2_acc: 94.45
# v4_acc: 86.70
# v10_acc: 72.20
# test_accuracy: 23.00
# top5_acc: 51.25
#
# Model: NICE4_sub-05.csv
# v2_acc: 89.80
# v4_acc: 75.70
# v10_acc: 55.30
# test_accuracy: 11.95
# top5_acc: 32.65
#
# Model: NICE4_sub-06.csv
# v2_acc: 92.30
# v4_acc: 82.40
# v10_acc: 66.50
# test_accuracy: 19.40
# top5_acc: 47.55
#
# Model: NICE4_sub-07.csv
# v2_acc: 93.70
# v4_acc: 85.50
# v10_acc: 71.65
# test_accuracy: 24.85
# top5_acc: 53.75
#
# Model: NICE4_sub-08.csv
# v2_acc: 96.05
# v4_acc: 90.10
# v10_acc: 79.85
# test_accuracy: 35.65
# top5_acc: 66.75
#
# Model: NICE4_sub-09.csv
# v2_acc: 93.00
# v4_acc: 82.90
# v10_acc: 67.15
# test_accuracy: 20.05
# top5_acc: 47.75
#
# Model: NICE4_sub-10.csv
# v2_acc: 95.30
# v4_acc: 87.10
# v10_acc: 75.25
# test_accuracy: 29.00
# top5_acc: 61.15
#
# Model: NICE_cross_exclude_sub-01.csv
# v2_acc: 82.65
# v4_acc: 65.10
# v10_acc: 42.65
# test_accuracy: 5.05
# top5_acc: 19.05
#
# Model: NICE_cross_exclude_sub-02.csv
# v2_acc: 81.10
# v4_acc: 64.00
# v10_acc: 41.25
# test_accuracy: 4.50
# top5_acc: 18.50
#
# Model: NICE_cross_exclude_sub-03.csv
# v2_acc: 80.75
# v4_acc: 62.80
# v10_acc: 40.50
# test_accuracy: 6.65
# top5_acc: 19.00
#
# Model: NICE_cross_exclude_sub-04.csv
# v2_acc: 88.05
# v4_acc: 73.40
# v10_acc: 53.80
# test_accuracy: 12.55
# top5_acc: 32.25
#
# Model: NICE_cross_exclude_sub-05.csv
# v2_acc: 74.95
# v4_acc: 53.60
# v10_acc: 32.15
# test_accuracy: 3.35
# top5_acc: 14.75
#
# Model: NICE_cross_exclude_sub-06.csv
# v2_acc: 84.35
# v4_acc: 66.40
# v10_acc: 43.85
# test_accuracy: 7.55
# top5_acc: 24.40
#
# Model: NICE_cross_exclude_sub-07.csv
# v2_acc: 81.80
# v4_acc: 62.75
# v10_acc: 42.55
# test_accuracy: 5.20
# top5_acc: 23.35
#
# Model: NICE_cross_exclude_sub-08.csv
# v2_acc: 84.20
# v4_acc: 67.75
# v10_acc: 45.10
# test_accuracy: 8.25
# top5_acc: 25.05
#
# Model: NICE_cross_exclude_sub-09.csv
# v2_acc: 79.05
# v4_acc: 61.50
# v10_acc: 39.65
# test_accuracy: 5.15
# top5_acc: 21.05
#
# Model: NICE_cross_exclude_sub-10.csv
# v2_acc: 90.00
# v4_acc: 75.65
# v10_acc: 55.05
# test_accuracy: 13.65
# top5_acc: 32.40
#
# Model: Projector_cross_exclude_sub-01.csv
# v2_acc: 73.80
# v4_acc: 48.40
# v10_acc: 30.15
# test_accuracy: 4.45
# top5_acc: 12.30
#
# Model: Projector_cross_exclude_sub-02.csv
# v2_acc: 81.45
# v4_acc: 65.10
# v10_acc: 44.65
# test_accuracy: 6.50
# top5_acc: 21.55
#
# Model: Projector_cross_exclude_sub-03.csv
# v2_acc: 82.60
# v4_acc: 66.10
# v10_acc: 45.35
# test_accuracy: 6.75
# top5_acc: 24.60
#
# Model: Projector_cross_exclude_sub-04.csv
# v2_acc: 83.35
# v4_acc: 66.15
# v10_acc: 45.75
# test_accuracy: 9.50
# top5_acc: 25.15
#
# Model: Projector_cross_exclude_sub-05.csv
# v2_acc: 79.55
# v4_acc: 60.45
# v10_acc: 38.90
# test_accuracy: 4.90
# top5_acc: 19.55
#
# Model: Projector_cross_exclude_sub-06.csv
# v2_acc: 77.10
# v4_acc: 58.20
# v10_acc: 36.15
# test_accuracy: 3.60
# top5_acc: 16.15
#
# Model: Projector_cross_exclude_sub-07.csv
# v2_acc: 79.25
# v4_acc: 61.30
# v10_acc: 40.70
# test_accuracy: 4.85
# top5_acc: 17.60
#
# Model: Projector_cross_exclude_sub-08.csv
# v2_acc: 84.35
# v4_acc: 67.55
# v10_acc: 49.95
# test_accuracy: 7.25
# top5_acc: 29.25
#
# Model: Projector_cross_exclude_sub-09.csv
# v2_acc: 81.05
# v4_acc: 59.35
# v10_acc: 39.05
# test_accuracy: 4.45
# top5_acc: 19.80
#
# Model: Projector_cross_exclude_sub-10.csv
# v2_acc: 87.25
# v4_acc: 72.75
# v10_acc: 53.45
# test_accuracy: 12.80
# top5_acc: 34.35
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-01.csv
# v2_acc: 75.55
# v4_acc: 55.85
# v10_acc: 32.05
# test_accuracy: 2.00
# top5_acc: 11.25
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-02.csv
# v2_acc: 76.20
# v4_acc: 55.60
# v10_acc: 32.10
# test_accuracy: 2.50
# top5_acc: 12.15
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-03.csv
# v2_acc: 72.95
# v4_acc: 49.05
# v10_acc: 25.60
# test_accuracy: 1.70
# top5_acc: 9.25
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-04.csv
# v2_acc: 79.85
# v4_acc: 59.15
# v10_acc: 36.70
# test_accuracy: 2.60
# top5_acc: 17.20
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-05.csv
# v2_acc: 69.90
# v4_acc: 45.65
# v10_acc: 22.90
# test_accuracy: 1.00
# top5_acc: 4.85
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-06.csv
# v2_acc: 80.10
# v4_acc: 58.80
# v10_acc: 38.25
# test_accuracy: 2.15
# top5_acc: 16.95
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-07.csv
# v2_acc: 78.50
# v4_acc: 58.60
# v10_acc: 37.70
# test_accuracy: 3.80
# top5_acc: 17.30
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-08.csv
# v2_acc: 76.75
# v4_acc: 57.80
# v10_acc: 34.95
# test_accuracy: 1.80
# top5_acc: 13.15
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-09.csv
# v2_acc: 69.75
# v4_acc: 42.10
# v10_acc: 20.50
# test_accuracy: 1.00
# top5_acc: 5.75
#
# Model: ShallowFBCSPNet_Encoder_cross_exclude_sub-10.csv
# v2_acc: 84.45
# v4_acc: 65.50
# v10_acc: 42.95
# test_accuracy: 6.30
# top5_acc: 24.55

# %%
    import os
    import pandas as pd

    # Directory path containing the CSV files
    directory_path = 'outputs'

    # Function to calculate the average of the last 10 epochs for a file
    def calculate_last_10_average(file_path):
        df = pd.read_csv(file_path)
        last_10_epochs = df.tail(10)
        return {
            'v2_acc': last_10_epochs['v2_acc'].mean(),
            'v4_acc': last_10_epochs['v4_acc'].mean(),
            'v10_acc': last_10_epochs['v10_acc'].mean(),
            'test_accuracy': last_10_epochs['test_accuracy'].mean(),  # TOP1 accuracy
            'top5_acc': last_10_epochs['top5_acc'].mean()  # TOP5 accuracy
        }

    # Group files by method and separate cross_exclude results
    method_groups = {}
    cross_exclude_groups = {}

    for filename in os.listdir(directory_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(directory_path, filename)
            if 'cross_exclude' in filename:
                # Handling cross_exclude results
                method_name = filename.split('_cross_exclude')[0]
                if method_name not in cross_exclude_groups:
                    cross_exclude_groups[method_name] = {}
                cross_exclude_groups[method_name][filename] = calculate_last_10_average(file_path)
            else:
                # Handling regular results
                method_name = filename.split('_')[0]
                if method_name not in method_groups:
                    method_groups[method_name] = {}
                method_groups[method_name][filename] = calculate_last_10_average(file_path)

    # Define a function to calculate averages and standard deviations
    def calculate_averages_and_stds(groups):
        results = {}
        metrics = ['v2_acc', 'v4_acc', 'v10_acc', 'test_accuracy', 'top5_acc']
        for method, subjects in groups.items():
            results[method] = {metric: {'mean': 0, 'std': 0} for metric in metrics}
            for metric in metrics:
                all_subjects_metric = [subjects[filename][metric] for filename in subjects]
                results[method][metric]['mean'] = sum(all_subjects_metric) / len(all_subjects_metric)
                results[method][metric]['std'] = pd.Series(all_subjects_metric).std()
        return results

    # Calculate and display the results
    regular_results = calculate_averages_and_stds(method_groups)
    cross_exclude_results = calculate_averages_and_stds(cross_exclude_groups)

    print("Regular Results:")
    for method, metrics in regular_results.items():
        print(f"Method: {method}")
        for metric, values in metrics.items():
            mean = "{:.2f}".format(values['mean'] * 100)
            std = "{:.2f}".format(values['std'] * 100)
            print(f"{metric} - Average: {mean}, Standard Deviation: {std}")
        print()

    print("Cross-Exclude Results:")
    for method, metrics in cross_exclude_results.items():
        print(f"Method: {method}")
        for metric, values in metrics.items():
            mean = "{:.2f}".format(values['mean'] * 100)
            std = "{:.2f}".format(values['std'] * 100)
            print(f"{metric} - Average: {mean}, Standard Deviation: {std}")
        print()
# Out:
# Regular Results:
# Method: NICE4
# v2_acc - Average: 92.99, Standard Deviation: 2.20
# v4_acc - Average: 83.81, Standard Deviation: 4.46
# v10_acc - Average: 68.87, Standard Deviation: 7.27
# test_accuracy - Average: 22.40, Standard Deviation: 6.62
# top5_acc - Average: 50.59, Standard Deviation: 9.59
#
# Method: NICE3
# v2_acc - Average: 94.60, Standard Deviation: 1.93
# v4_acc - Average: 86.88, Standard Deviation: 4.20
# v10_acc - Average: 73.89, Standard Deviation: 5.93
# test_accuracy - Average: 26.09, Standard Deviation: 6.96
# top5_acc - Average: 58.07, Standard Deviation: 8.16
#
# Method: NICE1
# v2_acc - Average: 93.89, Standard Deviation: 1.97
# v4_acc - Average: 85.38, Standard Deviation: 3.95
# v10_acc - Average: 71.63, Standard Deviation: 6.17
# test_accuracy - Average: 22.84, Standard Deviation: 5.87
# top5_acc - Average: 52.22, Standard Deviation: 8.34
#
# Method: MetaEEG
# v2_acc - Average: 91.14, Standard Deviation: 2.45
# v4_acc - Average: 79.59, Standard Deviation: 4.59
# v10_acc - Average: 62.62, Standard Deviation: 6.33
# test_accuracy - Average: 16.29, Standard Deviation: 4.35
# top5_acc - Average: 42.16, Standard Deviation: 7.56
#
# Method: NICE2
# v2_acc - Average: 94.44, Standard Deviation: 1.76
# v4_acc - Average: 86.11, Standard Deviation: 3.39
# v10_acc - Average: 71.89, Standard Deviation: 5.64
# test_accuracy - Average: 24.38, Standard Deviation: 6.56
# top5_acc - Average: 54.14, Standard Deviation: 8.08
#
# Cross-Exclude Results:
# Method: MetaEEG
# v2_acc - Average: 81.49, Standard Deviation: 3.52
# v4_acc - Average: 62.35, Standard Deviation: 6.44
# v10_acc - Average: 40.53, Standard Deviation: 7.19
# test_accuracy - Average: 6.16, Standard Deviation: 2.40
# top5_acc - Average: 20.45, Standard Deviation: 5.40
#
# Method: ATCNet_Encoder
# v2_acc - Average: 69.81, Standard Deviation: 3.41
# v4_acc - Average: 45.92, Standard Deviation: 4.34
# v10_acc - Average: 24.59, Standard Deviation: 4.48
# test_accuracy - Average: 1.73, Standard Deviation: 0.63
# top5_acc - Average: 8.45, Standard Deviation: 2.50
#
# Method: NICE3
# v2_acc - Average: 87.36, Standard Deviation: 3.97
# v4_acc - Average: 72.80, Standard Deviation: 7.02
# v10_acc - Average: 53.80, Standard Deviation: 8.41
# test_accuracy - Average: 11.84, Standard Deviation: 4.80
# top5_acc - Average: 33.73, Standard Deviation: 8.73
#
# Method: NICE1
# v2_acc - Average: 82.88, Standard Deviation: 5.18
# v4_acc - Average: 65.03, Standard Deviation: 8.51
# v10_acc - Average: 44.86, Standard Deviation: 9.85
# test_accuracy - Average: 8.04, Standard Deviation: 3.34
# top5_acc - Average: 24.62, Standard Deviation: 8.17
#
# Method: NICE
# v2_acc - Average: 82.69, Standard Deviation: 4.31
# v4_acc - Average: 65.30, Standard Deviation: 6.20
# v10_acc - Average: 43.66, Standard Deviation: 6.68
# test_accuracy - Average: 7.19, Standard Deviation: 3.44
# top5_acc - Average: 22.98, Standard Deviation: 5.81
#
# Method: ShallowFBCSPNet_Encoder
# v2_acc - Average: 76.40, Standard Deviation: 4.64
# v4_acc - Average: 54.81, Standard Deviation: 7.09
# v10_acc - Average: 32.37, Standard Deviation: 7.28
# test_accuracy - Average: 2.49, Standard Deviation: 1.57
# top5_acc - Average: 13.24, Standard Deviation: 5.98
#
# Method: NICE2
# v2_acc - Average: 83.30, Standard Deviation: 3.92
# v4_acc - Average: 65.80, Standard Deviation: 6.98
# v10_acc - Average: 44.84, Standard Deviation: 7.76
# test_accuracy - Average: 7.47, Standard Deviation: 2.84
# top5_acc - Average: 23.75, Standard Deviation: 6.86
#
# Method: NICE4
# v2_acc - Average: 87.41, Standard Deviation: 3.07
# v4_acc - Average: 72.85, Standard Deviation: 5.51
# v10_acc - Average: 53.15, Standard Deviation: 6.52
# test_accuracy - Average: 11.12, Standard Deviation: 3.26
# top5_acc - Average: 32.61, Standard Deviation: 6.78
#
# Method: Projector
# v2_acc - Average: 80.98, Standard Deviation: 3.81
# v4_acc - Average: 62.54, Standard Deviation: 6.64
# v10_acc - Average: 42.41, Standard Deviation: 6.83
# test_accuracy - Average: 6.51, Standard Deviation: 2.82
# top5_acc - Average: 22.03, Standard Deviation: 6.50
#
# Method: EEGITNet_Encoder
# v2_acc - Average: 77.47, Standard Deviation: 3.75
# v4_acc - Average: 55.75, Standard Deviation: 6.01
# v10_acc - Average: 33.60, Standard Deviation: 6.16
# test_accuracy - Average: 3.80, Standard Deviation: 2.01
# top5_acc - Average: 14.02, Standard Deviation: 3.89
